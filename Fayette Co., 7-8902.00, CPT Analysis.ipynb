# %% [markdown]
# # Fayette Co., 7-8902.00, CPT Analysis

# %%
import importlib
import csv
import pandas as pd
import numpy as np

# %%
import main
importlib.reload(main) # Reload py file to get updates in file if resaved
# Out:
# <module 'main' from 'c:\\Users\\clayt\\Documents\\Python Scripts\\CPTPython\\main.py'>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Summary of Results

# %%
r = pd.DataFrame([['1001A', 2, 0.05, 2606],
                  ['1004', 2, 0.05, 2606],
                  ['1006', 2.5, 0.05, 3274],
                  ['1008', 2.5, 0.05, 3274],
                  ['1012', 2, 0.05, 2606],
                  ['1013A', 2, 0.05, 2606],
                  ['1014', 2, 0.05, 3274]],
                columns=['Hole','q [MPa] int','fs [MPa] int','Allowable Bearing [psf]'])
r
# Out:
#     Hole  q [MPa] int  fs [MPa] int  Allowable Bearing [psf]
# 0  1001A          2.0          0.05                     2606
# 1   1004          2.0          0.05                     2606
# 2   1006          2.5          0.05                     3274
# 3   1008          2.5          0.05                     3274
# 4   1012          2.0          0.05                     2606
# 5  1013A          2.0          0.05                     2606
# 6   1014          2.0          0.05                     3274

# %% [markdown]
# # CPT Plotted Data

# %%
# Hole 1001CPT
name = "Hole 1001A"
with open("Fayette Co. 7-8902.00\\2021-01-06 7-8902.00 S-104-2020 1001.csv") as f:
    data = list(csv.reader(f))
    
    header = data[0]
    data = data[1:]
    
    H = [float(x[0]) for x in data]
    qc = [float(x[1]) for x in data]
    fs = [float(x[2]) for x in data]
    u2 = [float(x[3]) for x in data]

# Calculate qt
qt = []
for i, qc_value in enumerate(qc):
    qt.append(main.corrected_cone_resistance(qc_value,u2[i]))

push_1001 = {'name':name,
       header[0]: H,
       header[1]: qc,
       header[2]: fs,
       header[3]: u2,
       'qt [MPa]': qt}

# Hole Interpreted Layers
int_1001 = {'layer name':   ['Layer 1','Layer 2'],
            'layers [m]':   [1,1.72],
            'q [MPa] int': [2,2],
            'fs [MPa] int': [0.05,0.05]
           }

main.plot_push(push_1001['H [m]'],push_1001['qt [MPa]'],push_1001['fs [MPa]'],push_1001['u2 [MPa]'],
               title = 'Hole 1001A Data',depth_unit='ft',
               int_dict=int_1001,
               q_corrected=True)

# %%
# Hole 1004CPT
name = "Hole 1004"
with open("Fayette Co. 7-8902.00\\2021-01-06 7-8902.00 S-105-2020 1004.csv") as f:
    data = list(csv.reader(f))
    
    header = data[0]
    data = data[1:]
    
    H = [float(x[0]) for x in data]
    qc = [float(x[1]) for x in data]
    fs = [float(x[2]) for x in data]
    u2 = [float(x[3]) for x in data]

# Calculate qt
qt = []
for i, qc_value in enumerate(qc):
    qt.append(main.corrected_cone_resistance(qc_value,u2[i]))

push_1004 = {'name':name,
       header[0]: H,
       header[1]: qc,
       header[2]: fs,
       header[3]: u2,
       'qt [MPa]': qt}

# Hole Interpreted Layers
int_1004 = {'layer name':   ['Layer 1','Layer 2'],
            'layers [m]':   [2,4.16],
            'q [MPa] int': [2,2],
            'fs [MPa] int': [0.05,0.05]
           }

main.plot_push(push_1004['H [m]'],push_1004['qt [MPa]'],push_1004['fs [MPa]'],push_1004['u2 [MPa]'],
               title = 'Hole 1004 Data',depth_unit='ft',
               int_dict=int_1004,
               q_corrected=True)

# %%
# Hole 1006CPT
name = "Hole 1006"
with open("Fayette Co. 7-8902.00\\2021-01-06 7-8902.00 S-105-2020 1006.csv") as f:
    data = list(csv.reader(f))
    
    header = data[0]
    data = data[1:]
    
    H = [float(x[0]) for x in data]
    qc = [float(x[1]) for x in data]
    fs = [float(x[2]) for x in data]
    u2 = [float(x[3]) for x in data]

# Calculate qt
qt = []
for i, qc_value in enumerate(qc):
    qt.append(main.corrected_cone_resistance(qc_value,u2[i]))

push_1006 = {'name':name,
       header[0]: H,
       header[1]: qc,
       header[2]: fs,
       header[3]: u2,
       'qt [MPa]': qt}

# Hole Interpreted Layers
int_1006 = {'layer name':   ['Layer 1','Layer 2'],
            'layers [m]':   [2,5.62],
            'q [MPa] int': [2.5,2.5],
            'fs [MPa] int': [0.05,0.05]
           }

main.plot_push(push_1006['H [m]'],push_1006['qt [MPa]'],push_1006['fs [MPa]'],push_1006['u2 [MPa]'],
               title = 'Hole 1006 Data',depth_unit='ft',
               int_dict=int_1006,
               q_corrected=True)

# %%
# Hole 1008CPT
name = "Hole 1008"
with open("Fayette Co. 7-8902.00\\2021-01-06 7-8902.00 S-105-2020 1008.csv") as f:
    data = list(csv.reader(f))
    
    header = data[0]
    data = data[1:]
    
    H = [float(x[0]) for x in data]
    qc = [float(x[1]) for x in data]
    fs = [float(x[2]) for x in data]
    u2 = [float(x[3]) for x in data]

# Calculate qt
qt = []
for i, qc_value in enumerate(qc):
    qt.append(main.corrected_cone_resistance(qc_value,u2[i]))

push_1008 = {'name':name,
       header[0]: H,
       header[1]: qc,
       header[2]: fs,
       header[3]: u2,
       'qt [MPa]': qt}

# Hole Interpreted Layers
int_1008 = {'layer name':   ['Layer 1','Layer 2'],
            'layers [m]':   [2,5.08],
            'q [MPa] int': [2.5,2.5],
            'fs [MPa] int': [0.05,0.05]
           }

main.plot_push(push_1008['H [m]'],push_1008['qt [MPa]'],push_1008['fs [MPa]'],push_1008['u2 [MPa]'],
               title = 'Hole 1008 Data',depth_unit='ft',
               int_dict=int_1008,
               q_corrected=True)

# %%
# Hole 1012CPT
name = "Hole 1012"
with open("Fayette Co. 7-8902.00\\2021-01-19 7-8902.00 S-106-2020 1012.csv") as f:
    data = list(csv.reader(f))
    
    header = data[0]
    data = data[1:]
    
    H = [float(x[0]) for x in data]
    qc = [float(x[1]) for x in data]
    fs = [float(x[2]) for x in data]
    u2 = [float(x[3]) for x in data]

# Calculate qt
qt = []
for i, qc_value in enumerate(qc):
    qt.append(main.corrected_cone_resistance(qc_value,u2[i]))

push_1012 = {'name':name,
       header[0]: H,
       header[1]: qc,
       header[2]: fs,
       header[3]: u2,
       'qt [MPa]': qt}

# Hole Interpreted Layers
int_1012 = {'layer name':   ['Layer 1','Layer 2'],
            'layers [m]':   [2,6.28],
            'q [MPa] int': [2,2],
            'fs [MPa] int': [0.05,0.05]
           }

main.plot_push(push_1012['H [m]'],push_1012['qt [MPa]'],push_1012['fs [MPa]'],push_1012['u2 [MPa]'],
               title = 'Hole 1012 Data',depth_unit='ft',
               int_dict=int_1012,
               q_corrected=True)

# %%
# Hole 1013CPT
name = "Hole 1013A"
with open("Fayette Co. 7-8902.00\\2021-01-19 7-8902.00 S-106-2020 1013A.csv") as f:
    data = list(csv.reader(f))
    
    header = data[0]
    data = data[1:]
    
    H = [float(x[0]) for x in data]
    qc = [float(x[1]) for x in data]
    fs = [float(x[2]) for x in data]
    u2 = [float(x[3]) for x in data]

# Calculate qt
qt = []
for i, qc_value in enumerate(qc):
    qt.append(main.corrected_cone_resistance(qc_value,u2[i]))

push_1013 = {'name':name,
       header[0]: H,
       header[1]: qc,
       header[2]: fs,
       header[3]: u2,
       'qt [MPa]': qt}

# Hole Interpreted Layers
int_1013 = {'layer name':   ['Layer 1','Layer 2'],
            'layers [m]':   [2,5.9],
            'q [MPa] int': [2,2],
            'fs [MPa] int': [0.05,0.05]
           }

main.plot_push(push_1013['H [m]'],push_1013['qt [MPa]'],push_1013['fs [MPa]'],push_1013['u2 [MPa]'],
               title = 'Hole 1013A Data',depth_unit='ft',
               int_dict=int_1013,
               q_corrected=True)

# %%
# Hole 1014CPT
name = "Hole 1014"
with open("Fayette Co. 7-8902.00\\2021-01-19 7-8902.00 S-106-2020 1014.csv") as f:
    data = list(csv.reader(f))
    
    header = data[0]
    data = data[1:]
    
    H = [float(x[0]) for x in data]
    qc = [float(x[1]) for x in data]
    fs = [float(x[2]) for x in data]
    u2 = [float(x[3]) for x in data]

# Calculate qt
qt = []
for i, qc_value in enumerate(qc):
    qt.append(main.corrected_cone_resistance(qc_value,u2[i]))

push_1014 = {'name':name,
       header[0]: H,
       header[1]: qc,
       header[2]: fs,
       header[3]: u2,
       'qt [MPa]': qt}

# Hole Interpreted Layers
int_1014 = {'layer name':   ['Layer 1','Layer 2'],
            'layers [m]':   [2,5.14],
            'q [MPa] int': [2.5,2.5],
            'fs [MPa] int': [0.05,0.05]
           }

main.plot_push(push_1014['H [m]'],push_1014['qt [MPa]'],push_1014['fs [MPa]'],push_1014['u2 [MPa]'],
               title = 'Hole 1014 Data',depth_unit='ft',
               int_dict=int_1014,
               q_corrected=True)

# %% [markdown]
# # Bearing Capacity Calculation

# %%
def q_max(hs, qtnet, s_B_max, L, B):
    """
    Calculates maximum bearing pressure using direct CPT method for shallow foundations.

    Parameters
    ----------
        hs (float): Foundation Soil Formation Parameter
                    based on soil type
                    Clean Sands: 0.58
                    Silts: 1.12
                    Fissued Clays: 1.47
                    Intact Clays: 2.70
        qtnet (float): the mean value of net cone tip resistance 1.5*B below the founation bearing elevation
        s_B_max (float): maximum allowable settlement ratio (s/B)max
                         Can be based on soil type
                         Clean Sands: 12%
                         Silts: 10%
                         Fissured Clays: 7%
                         Intact Clays: 4%
        L (float): Length of footing
        B (float): Width of footing
    
    Returns
    -------
        float: maximum bearing pressure
    """

    q_max = hs * qtnet * (s_B_max)**0.5 * (L/B)**-0.345

    return q_max

def settlement_cal (B, hs, q_max, qtnet, FS, L):
    """
    Calculates Settlement using direct CPT method for shallow foundations.

    Parameters
    ----------
        B (float): Width of footing
        hs (float): Foundation Soil Formation Parameter
                    based on soil type
                    Clean Sands: 0.58
                    Silts: 1.12
                    Fissued Clays: 1.47
                    Intact Clays: 2.70
        q_max (float): maximum bearing pressure calculated using direct CPT method for shallow foundations.
        qtnet (float): the mean value of net cone tip resistance 1.5*B below the founation bearing elevation
        FS (float): Factor of Safety (general 3 for geotechnical engineering)
        L (float): Length of footing

    Return
    ------
        float: estimated settlement calculation  
    """

    settlement = B * ( (1/hs) * ((q_max/FS)/qtnet) * (L/B)**0.345 )**2

    return settlement

# %%
print('Hole 1001')
# Interpreted Soil CPT Parameters for the in-situ soil
fs = 0.05 #MPa
qt = 2 #MPa  

# Intrepreted Unit Weight
int_total_unit_weight = main.soil_weight_est(fs, "MPa", weight_return_units="pcf")
print("Interpreted Unit Weight:")
print("Unit Weight: {:.2f} kN/m3".format(main.convert(int_total_unit_weight, "pcf","kN/m3")))
print("Unit Weight: {:.2f} pcf".format(int_total_unit_weight))

# Footing Geometry
B = 5 #ft
L =  100 #ft 
z = 2 #ft Depth of footing
sigma_prime_vo = z * int_total_unit_weight #psf

# Mean Value of Net Cone Resistance 1.5*B below the foundation bearing elevation
qtnet = main.convert(qt,"MPa","psf") - (z + 1.5 * B) * int_total_unit_weight

# Foundation Soil Formation Parameter
hs = 2.70 # Intact Clays
s_B_max = 0.04 # Intact Clays

# Factor of Safety
FS = 3

# Maximum allowable bearing pressure
q_max_calculated = q_max(hs, qtnet, s_B_max, L, B)
print("")
print("Calculated Ultimate Bearing Capacity: {:.0f} psf".format(q_max_calculated))
print("Calculated Allowable Bearing Capacity: {:.0f} psf".format(q_max_calculated/FS))

# Estimated Settlement
settlement_est = settlement_cal(B, hs, q_max_calculated, qtnet, FS, L)
print("")
print("Calculated Settlement: {:.2f} in.".format(settlement_est*12))
# Out:
# Hole 1001
# Interpreted Unit Weight:
# Unit Weight: 17.70 kN/m3
# Unit Weight: 113.69 pcf
#
# Calculated Ultimate Bearing Capacity: 7817 psf
# Calculated Allowable Bearing Capacity: 2606 psf
#
# Calculated Settlement: 0.27 in.

# %%
print('Hole 1006')
# Interpreted Soil CPT Parameters for the in-situ soil
fs = 0.05 #MPa
qt = 2.5 #MPa

# Intrepreted Unit Weight
int_total_unit_weight = main.soil_weight_est(fs, "MPa", weight_return_units="pcf")
print("Interpreted Unit Weight:")
print("Unit Weight: {:.2f} kN/m3".format(main.convert(int_total_unit_weight, "pcf","kN/m3")))
print("Unit Weight: {:.2f} pcf".format(int_total_unit_weight))

# Footing Geometry
B = 5 #ft
L =  100 #ft 
z = 2 #ft Depth of footing
sigma_prime_vo = z * int_total_unit_weight #psf

# Mean Value of Net Cone Resistance 1.5*B below the foundation bearing elevation
qtnet = main.convert(qt,"MPa","psf") - (z + 1.5 * B) * int_total_unit_weight

# Foundation Soil Formation Parameter
hs = 2.70 # Intact Clays
s_B_max = 0.04 # Intact Clays

# Factor of Safety
FS = 3

# Maximum allowable bearing pressure
q_max_calculated = q_max(hs, qtnet, s_B_max, L, B)
print("")
print("Calculated Ultimate Bearing Capacity: {:.0f} psf".format(q_max_calculated))
print("Calculated Allowable Bearing Capacity: {:.0f} psf".format(q_max_calculated/FS))

# Estimated Settlement
settlement_est = settlement_cal(B, hs, q_max_calculated, qtnet, FS, L)
print("")
print("Calculated Settlement: {:.2f} in.".format(settlement_est*12))
# Out:
# Hole 1006
# Interpreted Unit Weight:
# Unit Weight: 17.70 kN/m3
# Unit Weight: 113.69 pcf
#
# Calculated Ultimate Bearing Capacity: 9823 psf
# Calculated Allowable Bearing Capacity: 3274 psf
#
# Calculated Settlement: 0.27 in.
